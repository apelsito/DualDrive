# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Cargamos los CSV

# %%
df_gastos= pd.read_csv("../datos/01_Balance/gastos.csv")
df_ingresos= pd.read_csv("../datos/01_Balance/ingresos.csv",index_col="Unnamed: 0")

# %%
df_gastos["año"].unique()
# Out:
# array([2020, 2019, 2018, 2016, 2017, 2015, 2014, 2010, 2011, 2013, 2012])

# %%
len(df_gastos["ncodi"].unique())
# Out:
# 857

# %%
df_gastos
# Out:
#        año   ncodi  totalcompra  producfarma  materialsani  implantes  \
# 0     2020   113.0      1535894     344330.0        169443        0.0
# 1     2020   619.0      7884157     971762.0       1749006   493444.0
# 2     2020   163.0      5453290     126493.0       1412366   574127.0
# 3     2020   131.0       245802      72318.0         52506        0.0
# 4     2020   375.0       762218     114702.0        106844       60.0
# ...    ...     ...          ...          ...           ...        ...
# 8445  2012   970.0       271324       8510.0        166422        0.0
# 8446  2012  1019.0      1687968     126665.0         94290        0.0
# 8447  2012  1016.0      5418532     336983.0       1152639   145404.0
# 8448  2012  1047.0     15537164    5516672.0       5255744   565150.0
# 8449  2012   635.0     14508459    6275019.0       4311556   231481.0
#
#       restomateriasani  servcontratado  trabajocontratado  xrestocompras  \
# ...

# %%
df_ingresos["año"].unique()
# Out:
# array([2013, 2014, 2015, 2012, 2017, 2010, 2019, 2021, 2020, 2018, 2011,
#        2016])

# %%
len(df_ingresos["ncodi"].unique())
# Out:
# 2424

# %%
df_ingresos.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_ingresos["tipo"].unique()
# Out:
# array(['Hospital', 'consulExter', 'CMA', 'hospDia', 'Urgencia', 'hospDom'],
#       dtype=object)

# %%
df_ingresos["ncodi"].str.replace(",",".")
# Out:
# 0        990.00
# 1        680.00
# 2        411.00
# 3        241.00
# 4        558.00
#           ...
# 55321       970
# 55322      1019
# 55323      1016
# 55324      1047
# 55325       635
# Name: ncodi, Length: 55326, dtype: object

# %%
df_ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55326 entries, 0 to 55325
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               55326 non-null  int64
#  1   particulares             53952 non-null  float64
#  2   aseguradoras             55322 non-null  float64
#  3   aseguradoras_enfermedad  53952 non-null  float64
#  4   aseguradoreas_trafico    53859 non-null  float64
#  5   mutuas                   53942 non-null  float64
#  6   tipo                     55326 non-null  object
#  7   año                      55326 non-null  int64
#  8   ncodi                    55308 non-null  object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.8+ MB

# %%
df_ingresos.sample(10)
# Out:
#        particulares  aseguradoras  aseguradoras_enfermedad  \
# 26674       21740.0     1387043.0                1387043.0
# 44643           0.0       23114.0                  18752.0
# 38157        1604.0           0.0                      0.0
# 6119      1070797.0     4866453.0                4796354.0
# 33042        8408.0      371108.0                 343218.0
# 34926           0.0           0.0                      0.0
# 3848            0.0           0.0                      0.0
# 13761           0.0        8675.0                   8675.0
# 27466           0.0           0.0                      0.0
# 30428           NaN           0.0                      NaN
#
#        aseguradoreas_trafico    mutuas         tipo   año   ncodi
# 26674                    0.0   86195.0     Urgencia  2010  510,00
# 44643                 4362.0    4362.0     Urgencia  2018     297
# 38157                    0.0       0.0  consulExter  2020     312
# ...

# %%
df_ingresos["aseguradoras"].unique().tolist()
# Out:
# [103677.0,
#  478280.0,
#  1803352.0,
#  0.0,
#  63557.0,
#  2343056.0,
#  69348.0,
#  52238.0,
#  158145.0,
#  4250824.0,
#  517596.0,
#  46790.0,
#  1193011.0,
#  3013094.0,
#  823722.0,
#  3163.0,
#  141608.0,
#  54509.0,
#  46624.0,
#  14528424.0,
#  7101982.0,
#  633021.0,
#  96456.0,
#  2670208.0,
#  228103.0,
#  516219.0,
#  1636.0,
#  514913.0,
#  2279182.0,
#  12833.0,
#  114325.0,
#  297.0,
#  324898.0,
#  374783.0,
#  26800.0,
#  135724.0,
#  169959.0,
#  19945063.0,
#  10485936.0,
#  9250272.0,
#  138754.0,
#  31654594.0,
#  11964.0,
#  217474.0,
#  4914686.0,
#  62669.0,
#  50043.0,
#  2.0,
#  521736.0,
#  38714.0,
#  10348423.0,
#  436686.0,
#  1237257.0,
#  71285.0,
#  22636211.0,
#  11092555.0,
#  19896949.0,
#  176681.0,
#  2800530.0,
#  1568.0,
#  491053.0,
#  2087464.0,
#  407340.0,
#  16544511.0,
#  20704400.0,
#  6212291.0,
#  55785426.0,
#  11891177.0,
#  1778845.0,
#  1806119.0,
#  22886266.0,
#  37987871.0,
#  35881378.0,
#  457920.0,
#  6424125.0,
# ...

# %%
df_gastos= pd.read_csv("../datos/01_Balance/gastos.csv")

# %%
cond = df_gastos["ncodi"].isnull() == True
df_gastos.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_gastos
# Out:
#        año   ncodi  totalcompra  producfarma  materialsani  implantes  \
# 0     2020   113.0      1535894     344330.0        169443        0.0
# 1     2020   619.0      7884157     971762.0       1749006   493444.0
# 2     2020   163.0      5453290     126493.0       1412366   574127.0
# 3     2020   131.0       245802      72318.0         52506        0.0
# 4     2020   375.0       762218     114702.0        106844       60.0
# ...    ...     ...          ...          ...           ...        ...
# 8445  2012   970.0       271324       8510.0        166422        0.0
# 8446  2012  1019.0      1687968     126665.0         94290        0.0
# 8447  2012  1016.0      5418532     336983.0       1152639   145404.0
# 8448  2012  1047.0     15537164    5516672.0       5255744   565150.0
# 8449  2012   635.0     14508459    6275019.0       4311556   231481.0
#
#       restomateriasani  servcontratado  trabajocontratado  xrestocompras  \
# ...

# %%
df_gastos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8450 entries, 0 to 8449
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   año                8450 non-null   int64
#  1   ncodi              8448 non-null   float64
#  2   totalcompra        8450 non-null   int64
#  3   producfarma        8449 non-null   float64
#  4   materialsani       8450 non-null   int64
#  5   implantes          8348 non-null   float64
#  6   restomateriasani   8439 non-null   float64
#  7   servcontratado     8392 non-null   float64
#  8   trabajocontratado  8419 non-null   float64
#  9   xrestocompras      8432 non-null   float64
#  10  variaexistencias   8271 non-null   float64
#  11  servexteriores     8450 non-null   int64
#  12  sumistro           8446 non-null   float64
#  13  xrestoserviexter   8442 non-null   float64
#  14  gastopersonal      8450 non-null   int64
#  15  sueldos            8450 non-null   int64
# ...
